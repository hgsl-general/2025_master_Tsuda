# %%
#各年代ごとに各モデルの平均を計算
import netCDF4 as nc
import numpy as np
#ちゃんと反映されましたね
# 年代のリスト
years = [900, 1400, 1700, 1850, 1950, 2000]

for year in years:
    # netCDFファイルを開く(降水量を取得)
    if year==900:
        CSIRO_pr=nc.Dataset('/work/a06/tsuda/m1/CSIRO/annual_mean_pr_Amon_CSIRO-Mk3L-1-2_900.nc')
        CSIRO_tas=nc.Dataset('/work/a06/tsuda/m1/CSIRO/annual_mean_tas_Amon_CSIRO-Mk3L-1-2_900.nc')
        IPSL_pr=nc.Dataset('/work/a06/tsuda/m1/IPSL/annual_mean_pr_IPSL_900.nc')
        IPSL_tas=nc.Dataset('/work/a06/tsuda/m1/IPSL/annual_mean_tas_IPSL_900.nc')
        HadCM3_pr=nc.Dataset('/work/a06/tsuda/m1/HadCM3/annual_mean_pr_HadCM3_900.nc')
        HadCM3_tas=nc.Dataset('/work/a06/tsuda/m1/HadCM3/annual_mean_tas_HadCM3_900.nc')
        
        GISS121_pr=nc.Dataset('/work/a06/tsuda/m1/GISS121/annual_mean_pr_GISS121_900.nc')
        GISS121_tas=nc.Dataset('/work/a06/tsuda/m1/GISS121/annual_mean_tas_GISS121_900.nc')
        GISS1221_pr=nc.Dataset('/work/a06/tsuda/m1/GISS1221/annual_mean_pr_GISS1221(122)_900.nc')
        GISS1221_tas=nc.Dataset('/work/a06/tsuda/m1/GISS1221/annual_mean_tas_GISS1221(122)_900.nc')
        GISS124_pr=nc.Dataset('/work/a06/tsuda/m1/GISS124/annual_mean_pr_GISS124_900.nc')
        GISS124_tas=nc.Dataset('/work/a06/tsuda/m1/GISS124/annual_mean_tas_GISS124_900.nc')
        GISS125_pr=nc.Dataset('/work/a06/tsuda/m1/GISS125/annual_mean_pr_GISS125_900.nc')
        GISS125_tas=nc.Dataset('/work/a06/tsuda/m1/GISS125/annual_mean_tas_GISS125_900.nc')
        GISS127_pr =nc.Dataset('/work/a06/tsuda/m1/GISS127/annual_mean_pr_GISS127_900.nc')
        GISS127_tas =nc.Dataset('/work/a06/tsuda/m1/GISS127/annual_mean_tas_GISS127_900.nc')
        GISS128_pr =nc.Dataset('/work/a06/tsuda/m1/GISS128/annual_mean_pr_GISS128_900.nc')
        GISS128_tas =nc.Dataset('/work/a06/tsuda/m1/GISS128/annual_mean_tas_GISS128_900.nc')

    if year==1400:
        CSIRO_pr=nc.Dataset('/work/a06/tsuda/m1/CSIRO/annual_mean_pr_Amon_CSIRO-Mk3L-1-2_1400.nc')
        CSIRO_tas=nc.Dataset('/work/a06/tsuda/m1/CSIRO/annual_mean_tas_Amon_CSIRO-Mk3L-1-2_1400.nc')
        IPSL_pr=nc.Dataset('/work/a06/tsuda/m1/IPSL/annual_mean_pr_IPSL_1400.nc')
        IPSL_tas=nc.Dataset('/work/a06/tsuda/m1/IPSL/annual_mean_tas_IPSL_1400.nc')
        HadCM3_pr=nc.Dataset('/work/a06/tsuda/m1/HadCM3/annual_mean_pr_HadCM3_1400.nc')
        HadCM3_tas=nc.Dataset('/work/a06/tsuda/m1/HadCM3/annual_mean_tas_HadCM3_1400.nc')
        
        GISS121_pr=nc.Dataset('/work/a06/tsuda/m1/GISS121/annual_mean_pr_GISS121_1400.nc')
        GISS121_tas=nc.Dataset('/work/a06/tsuda/m1/GISS121/annual_mean_tas_GISS121_1400.nc')
        GISS1221_pr=nc.Dataset('/work/a06/tsuda/m1/GISS1221/annual_mean_pr_GISS1221(122)_1400.nc')
        GISS1221_tas=nc.Dataset('/work/a06/tsuda/m1/GISS1221/annual_mean_tas_GISS1221(122)_1400.nc')
        GISS124_pr=nc.Dataset('/work/a06/tsuda/m1/GISS124/annual_mean_pr_GISS124_1400.nc')
        GISS124_tas=nc.Dataset('/work/a06/tsuda/m1/GISS124/annual_mean_tas_GISS124_1400.nc')
        GISS125_pr=nc.Dataset('/work/a06/tsuda/m1/GISS125/annual_mean_pr_GISS125_1400.nc')
        GISS125_tas=nc.Dataset('/work/a06/tsuda/m1/GISS125/annual_mean_tas_GISS125_1400.nc')
        GISS127_pr =nc.Dataset('/work/a06/tsuda/m1/GISS127/annual_mean_pr_GISS127_1400.nc')
        GISS127_tas =nc.Dataset('/work/a06/tsuda/m1/GISS127/annual_mean_tas_GISS127_1400.nc')
        GISS128_pr =nc.Dataset('/work/a06/tsuda/m1/GISS128/annual_mean_pr_GISS128_1400.nc')
        GISS128_tas =nc.Dataset('/work/a06/tsuda/m1/GISS128/annual_mean_tas_GISS128_1400.nc')

    if year==1700:
        CSIRO_pr=nc.Dataset('/work/a06/tsuda/m1/CSIRO/annual_mean_pr_Amon_CSIRO-Mk3L-1-2_1700.nc')
        CSIRO_tas=nc.Dataset('/work/a06/tsuda/m1/CSIRO/annual_mean_tas_Amon_CSIRO-Mk3L-1-2_1700.nc')
        IPSL_pr=nc.Dataset('/work/a06/tsuda/m1/IPSL/annual_mean_pr_IPSL_1700.nc')
        IPSL_tas=nc.Dataset('/work/a06/tsuda/m1/IPSL/annual_mean_tas_IPSL_1700.nc')
        HadCM3_pr=nc.Dataset('/work/a06/tsuda/m1/HadCM3/annual_mean_pr_HadCM3_1700.nc')
        HadCM3_tas=nc.Dataset('/work/a06/tsuda/m1/HadCM3/annual_mean_tas_HadCM3_1700.nc')
        
        GISS121_pr=nc.Dataset('/work/a06/tsuda/m1/GISS121/annual_mean_pr_GISS121_1700.nc')
        GISS121_tas=nc.Dataset('/work/a06/tsuda/m1/GISS121/annual_mean_tas_GISS121_1700.nc')
        GISS1221_pr=nc.Dataset('/work/a06/tsuda/m1/GISS1221/annual_mean_pr_GISS1221(122)_1700.nc')
        GISS1221_tas=nc.Dataset('/work/a06/tsuda/m1/GISS1221/annual_mean_tas_GISS1221(122)_1700.nc')
        GISS124_pr=nc.Dataset('/work/a06/tsuda/m1/GISS124/annual_mean_pr_GISS124_1700.nc')
        GISS124_tas=nc.Dataset('/work/a06/tsuda/m1/GISS124/annual_mean_tas_GISS124_1700.nc')
        GISS125_pr=nc.Dataset('/work/a06/tsuda/m1/GISS125/annual_mean_pr_GISS125_1700.nc')
        GISS125_tas=nc.Dataset('/work/a06/tsuda/m1/GISS125/annual_mean_tas_GISS125_1700.nc')
        GISS127_pr =nc.Dataset('/work/a06/tsuda/m1/GISS127/annual_mean_pr_GISS127_1700.nc')
        GISS127_tas =nc.Dataset('/work/a06/tsuda/m1/GISS127/annual_mean_tas_GISS127_1700.nc')
        GISS128_pr =nc.Dataset('/work/a06/tsuda/m1/GISS128/annual_mean_pr_GISS128_1700.nc')
        GISS128_tas =nc.Dataset('/work/a06/tsuda/m1/GISS128/annual_mean_tas_GISS128_1700.nc')

    if year==1850:
        CSIRO_pr=nc.Dataset('/work/a06/tsuda/m1/CSIRO/annual_mean_pr_Amon_CSIRO-Mk3L-1-2_1850.nc')
        CSIRO_tas=nc.Dataset('/work/a06/tsuda/m1/CSIRO/annual_mean_tas_Amon_CSIRO-Mk3L-1-2_1850.nc')
        IPSL_pr=nc.Dataset('/work/a06/tsuda/m1/IPSL/annual_mean_pr_IPSL_1850.nc')
        IPSL_tas=nc.Dataset('/work/a06/tsuda/m1/IPSL/annual_mean_tas_IPSL_1850.nc')
        HadCM3_pr=nc.Dataset('/work/a06/tsuda/m1/HadCM3/annual_mean_pr_HadCM3_1850.nc')
        HadCM3_tas=nc.Dataset('/work/a06/tsuda/m1/HadCM3/annual_mean_tas_HadCM3_1850.nc')
        
        GISS121_pr=nc.Dataset('/work/a06/tsuda/m1/GISS121/annual_mean_pr_GISS121_1850.nc')
        GISS121_tas=nc.Dataset('/work/a06/tsuda/m1/GISS121/annual_mean_tas_GISS121_1850.nc')
        GISS1221_pr=nc.Dataset('/work/a06/tsuda/m1/GISS1221/annual_mean_pr_GISS1221(122)_1850.nc')
        GISS1221_tas=nc.Dataset('/work/a06/tsuda/m1/GISS1221/annual_mean_tas_GISS1221(122)_1850.nc')
        GISS124_pr=nc.Dataset('/work/a06/tsuda/m1/GISS124/annual_mean_pr_GISS124_1850.nc')
        GISS124_tas=nc.Dataset('/work/a06/tsuda/m1/GISS124/annual_mean_tas_GISS124_1850.nc')
        GISS125_pr=nc.Dataset('/work/a06/tsuda/m1/GISS125/annual_mean_pr_GISS125_1850.nc')
        GISS125_tas=nc.Dataset('/work/a06/tsuda/m1/GISS125/annual_mean_tas_GISS125_1850.nc')
        GISS127_pr =nc.Dataset('/work/a06/tsuda/m1/GISS127/annual_mean_pr_GISS127_1850.nc')
        GISS127_tas =nc.Dataset('/work/a06/tsuda/m1/GISS127/annual_mean_tas_GISS127_1850.nc')
        GISS128_pr =nc.Dataset('/work/a06/tsuda/m1/GISS128/annual_mean_pr_GISS128_1850.nc')
        GISS128_tas =nc.Dataset('/work/a06/tsuda/m1/GISS128/annual_mean_tas_GISS128_1850.nc')

    if year==1950:
        CSIRO_pr=nc.Dataset('/work/a06/tsuda/m1/CSIRO/annual_mean_pr_Amon_CSIRO-Mk3L-1-2_1950.nc')
        CSIRO_tas=nc.Dataset('/work/a06/tsuda/m1/CSIRO/annual_mean_tas_Amon_CSIRO-Mk3L-1-2_1950.nc')
        IPSL_pr=nc.Dataset('/work/a06/tsuda/m1/IPSL/annual_mean_pr_IPSL_1950.nc')
        IPSL_tas=nc.Dataset('/work/a06/tsuda/m1/IPSL/annual_mean_tas_IPSL_1950.nc')
        HadCM3_pr=nc.Dataset('/work/a06/tsuda/m1/HadCM3/annual_mean_pr_HadCM3_1950.nc')
        HadCM3_tas=nc.Dataset('/work/a06/tsuda/m1/HadCM3/annual_mean_tas_HadCM3_1950.nc')
        
        GISS121_pr=nc.Dataset('/work/a06/tsuda/m1/GISS121/annual_mean_pr_GISS121_1950.nc')
        GISS121_tas=nc.Dataset('/work/a06/tsuda/m1/GISS121/annual_mean_tas_GISS121_1950.nc')
        GISS1221_pr=nc.Dataset('/work/a06/tsuda/m1/GISS1221/annual_mean_pr_GISS1221(122)_1950.nc')
        GISS1221_tas=nc.Dataset('/work/a06/tsuda/m1/GISS1221/annual_mean_tas_GISS1221(122)_1950.nc')
        GISS124_pr=nc.Dataset('/work/a06/tsuda/m1/GISS124/annual_mean_pr_GISS124_1950.nc')
        GISS124_tas=nc.Dataset('/work/a06/tsuda/m1/GISS124/annual_mean_tas_GISS124_1950.nc')
        GISS125_pr=nc.Dataset('/work/a06/tsuda/m1/GISS125/annual_mean_pr_GISS125_1950.nc')
        GISS125_tas=nc.Dataset('/work/a06/tsuda/m1/GISS125/annual_mean_tas_GISS125_1950.nc')
        GISS127_pr =nc.Dataset('/work/a06/tsuda/m1/GISS127/annual_mean_pr_GISS127_1950.nc')
        GISS127_tas =nc.Dataset('/work/a06/tsuda/m1/GISS127/annual_mean_tas_GISS127_1950.nc')
        GISS128_pr =nc.Dataset('/work/a06/tsuda/m1/GISS128/annual_mean_pr_GISS128_1950.nc')
        GISS128_tas =nc.Dataset('/work/a06/tsuda/m1/GISS128/annual_mean_tas_GISS128_1950.nc')

    if year==2000:
        CSIRO_pr=nc.Dataset('/work/a06/tsuda/m1/CSIRO/annual_mean_pr_Amon_CSIRO-Mk3L-1-2_2000.nc')
        CSIRO_tas=nc.Dataset('/work/a06/tsuda/m1/CSIRO/annual_mean_tas_Amon_CSIRO-Mk3L-1-2_2000.nc')
        IPSL_pr=nc.Dataset('/work/a06/tsuda/m1/IPSL/annual_mean_pr_IPSL_2000.nc')
        IPSL_tas=nc.Dataset('/work/a06/tsuda/m1/IPSL/annual_mean_tas_IPSL_2000.nc')
        HadCM3_pr=nc.Dataset('/work/a06/tsuda/m1/HadCM3/annual_mean_pr_HadCM3_2000.nc')
        HadCM3_tas=nc.Dataset('/work/a06/tsuda/m1/HadCM3/annual_mean_tas_HadCM3_2000.nc')
        
        GISS121_pr=nc.Dataset('/work/a06/tsuda/m1/GISS121/annual_mean_pr_GISS121_2000.nc')
        GISS121_tas=nc.Dataset('/work/a06/tsuda/m1/GISS121/annual_mean_tas_GISS121_2000.nc')
        GISS1221_pr=nc.Dataset('/work/a06/tsuda/m1/GISS1221/annual_mean_pr_GISS1221(122)_2000.nc')
        GISS1221_tas=nc.Dataset('/work/a06/tsuda/m1/GISS1221/annual_mean_tas_GISS1221(122)_2000.nc')
        GISS124_pr=nc.Dataset('/work/a06/tsuda/m1/GISS124/annual_mean_pr_GISS124_2000.nc')
        GISS124_tas=nc.Dataset('/work/a06/tsuda/m1/GISS124/annual_mean_tas_GISS124_2000.nc')
        GISS125_pr=nc.Dataset('/work/a06/tsuda/m1/GISS125/annual_mean_pr_GISS125_2000.nc')
        GISS125_tas=nc.Dataset('/work/a06/tsuda/m1/GISS125/annual_mean_tas_GISS125_2000.nc')
        GISS127_pr =nc.Dataset('/work/a06/tsuda/m1/GISS127/annual_mean_pr_GISS127_2000.nc')
        GISS127_tas =nc.Dataset('/work/a06/tsuda/m1/GISS127/annual_mean_tas_GISS127_2000.nc')
        GISS128_pr =nc.Dataset('/work/a06/tsuda/m1/GISS128/annual_mean_pr_GISS128_2000.nc')
        GISS128_tas =nc.Dataset('/work/a06/tsuda/m1/GISS128/annual_mean_tas_GISS128_2000.nc')

    # 各時代の平均を計算 (先にGISSの平均を計算して、それを一つとして用いる）
    GISS_mean_pr = (GISS121_pr.variables['annual_mean_pr'][:] + GISS1221_pr.variables['annual_mean_pr'][:] + GISS124_pr.variables['annual_mean_pr'][:] + GISS125_pr.variables['annual_mean_pr'][:] + GISS127_pr.variables['annual_mean_pr'][:] + GISS128_pr.variables['annual_mean_pr'][:])/6
    GISS_mean_tas = (GISS121_tas.variables['annual_mean_tas'][:] + GISS1221_tas.variables['annual_mean_tas'][:] + GISS124_tas.variables['annual_mean_tas'][:] + GISS125_tas.variables['annual_mean_tas'][:] + GISS127_tas.variables['annual_mean_tas'][:] + GISS128_tas.variables['annual_mean_tas'][:])/6
    
    # NumPy配列に変換
    GISS_mean_pr_np = np.array(GISS_mean_pr)
    GISS_mean_tas_np = np.array(GISS_mean_tas)

    print(year)

    # 各モデルのデータをNumPy配列に変換
    CSIRO_pr_np = np.array(CSIRO_pr.variables['annual_mean_pr'][:])
    IPSL_pr_np = np.array(IPSL_pr.variables['annual_mean_pr'][:])
    HadCM3_pr_np = np.array(HadCM3_pr.variables['annual_mean_pr'][:])
    GISS_mean_pr_np = np.array(GISS_mean_pr)

    CSIRO_tas_np = np.array(CSIRO_tas.variables['annual_mean_tas'][:])
    IPSL_tas_np = np.array(IPSL_tas.variables['annual_mean_tas'][:])
    HadCM3_tas_np = np.array(HadCM3_tas.variables['annual_mean_tas'][:])
    GISS_mean_tas_np = np.array(GISS_mean_tas)

    # NumPy配列の平均を計算
    mean_pr[year] = (CSIRO_pr_np + IPSL_pr_np + HadCM3_pr_np + GISS_mean_pr_np) / 4
    mean_tas[year] = (CSIRO_tas_np + IPSL_tas_np + HadCM3_tas_np + GISS_mean_tas_np) / 4
    
    np.save(f'/work/a06/tsuda/m1/mean_pr_{year}.npy', mean_pr[year])
    np.save(f'/work/a06/tsuda/m1/mean_tas_{year}.npy', mean_tas[year])
# Out:
# 900
# 1400
# 1700
# 1850
# 1950
# 2000
